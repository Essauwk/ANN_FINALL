# %%
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (Conv2D, SeparableConv2D, BatchNormalization, Activation,
                                     Dropout, AveragePooling2D, GlobalAveragePooling2D,
                                     Input, MaxPooling2D, Flatten)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import cv2
import imutils
import os

# %%
dataset_path = 'fer2013/fer2013/fer2013.csv'
image_size = (48, 48)


def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(48, 48)
        face = cv2.resize(face.astype('uint8'), image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions


def preprocess_input(x, v2=True):
    x = x.astype('float32') / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x

# %%
def simple_CNN(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(16, (7, 7), padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(16, (7, 7), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2), padding='same'))
    model.add(Dropout(.5))

    model.add(Conv2D(32, (5, 5), padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (5, 5), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2), padding='same'))
    model.add(Dropout(.5))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2), padding='same'))
    model.add(Dropout(.5))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2), padding='same'))
    model.add(Dropout(.5))

    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(num_classes, (3, 3), padding='same'))
    model.add(GlobalAveragePooling2D())
    model.add(Activation('softmax', name='predictions'))
    return model

# %%
def mini_XCEPTION(input_shape, num_classes, l2_regularization=0.01):
    regularization = l2(l2_regularization)

    img_input = Input(input_shape)
    x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    for filters in [16, 32, 64, 128]:
        residual = Conv2D(filters, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
        residual = BatchNormalization()(residual)

        x = SeparableConv2D(filters, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = SeparableConv2D(filters, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
        x = BatchNormalization()(x)

        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
        x = layers.add([x, residual])

    x = Conv2D(num_classes, (3, 3), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    output = Activation('softmax', name='predictions')(x)

    return Model(img_input, output)

# %%
input_shape = (64, 64, 1)
num_classes = 7
model = simple_CNN((48, 48, 1), num_classes)
model.summary()
# Out:
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 16)     │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 16)     │        12,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 24, 24, 16)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 32)     │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 32)     │        25,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 12, 12, 32)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 6, 6, 64)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 3, 3, 128)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 3, 3, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 3, 3, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 3, 3, 7)        │        16,135 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 7)              │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Activation)        │ (None, 7)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 642,935 (2.45 MB)
#  Trainable params: 641,463 (2.45 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %%
input_shape = (48, 48, 1)
num_classes = 7
batch_size = 32
num_epochs = 100
patience = 50
base_path = 'models/emotion_model'

faces, emotions = load_fer2013()
faces = preprocess_input(faces)

xtrain, xtest, ytrain, ytest = train_test_split(faces, emotions, test_size=0.2, shuffle=True)

data_generator = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=.1,
    horizontal_flip=True
)

model = simple_CNN(input_shape, num_classes)
# لو عايز تجرب simple_CNN بدلها:
# model = simple_CNN(input_shape, num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

callbacks = [
    CSVLogger(base_path + '.log'),
    ModelCheckpoint(base_path + '.keras', monitor='val_loss', save_best_only=True, verbose=1)
,
    EarlyStopping(monitor='val_loss', patience=patience),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=int(patience / 4), verbose=1)
]

model.fit(
    data_generator.flow(xtrain, ytrain, batch_size=batch_size),
    steps_per_epoch=len(xtrain) // batch_size,
    epochs=num_epochs,
    verbose=1,
    callbacks=callbacks,
    validation_data=(xtest, ytest)
)
# Out:
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.2392 - loss: 1.8842
# Epoch 1: val_loss improved from inf to 1.60569, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 112s 117ms/step - accuracy: 0.2392 - loss: 1.8841 - val_accuracy: 0.3759 - val_loss: 1.6057 - learning_rate: 0.0010
# Epoch 2/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:53 126ms/step - accuracy: 0.1562 - loss: 1.7934
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_loss did not improve from 1.60569
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.1562 - loss: 1.7934 - val_accuracy: 0.3695 - val_loss: 1.6114 - learning_rate: 0.0010
# Epoch 3/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3320 - loss: 1.6766
# Epoch 3: val_loss improved from 1.60569 to 1.54451, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 99s 110ms/step - accuracy: 0.3320 - loss: 1.6766 - val_accuracy: 0.4036 - val_loss: 1.5445 - learning_rate: 0.0010
# Epoch 4/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:33 104ms/step - accuracy: 0.3438 - loss: 1.5951
# Epoch 4: val_loss did not improve from 1.54451
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3438 - loss: 1.5951 - val_accuracy: 0.4009 - val_loss: 1.5467 - learning_rate: 0.0010
# Epoch 5/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3599 - loss: 1.6134
# Epoch 5: val_loss improved from 1.54451 to 1.52419, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 105s 117ms/step - accuracy: 0.3599 - loss: 1.6134 - val_accuracy: 0.4114 - val_loss: 1.5242 - learning_rate: 0.0010
# Epoch 6/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 3:16 220ms/step - accuracy: 0.4375 - loss: 1.3967
# Epoch 6: val_loss improved from 1.52419 to 1.51980, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.4375 - loss: 1.3967 - val_accuracy: 0.4113 - val_loss: 1.5198 - learning_rate: 0.0010
# Epoch 7/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3843 - loss: 1.5702
# Epoch 7: val_loss improved from 1.51980 to 1.47971, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 91s 102ms/step - accuracy: 0.3843 - loss: 1.5702 - val_accuracy: 0.4218 - val_loss: 1.4797 - learning_rate: 0.0010
# Epoch 8/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:33 104ms/step - accuracy: 0.4375 - loss: 1.4213
# Epoch 8: val_loss improved from 1.47971 to 1.47144, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.4375 - loss: 1.4213 - val_accuracy: 0.4248 - val_loss: 1.4714 - learning_rate: 0.0010
# Epoch 9/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4051 - loss: 1.5260
# Epoch 9: val_loss improved from 1.47144 to 1.41196, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 79s 88ms/step - accuracy: 0.4051 - loss: 1.5260 - val_accuracy: 0.4561 - val_loss: 1.4120 - learning_rate: 0.0010
# Epoch 10/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:11 79ms/step - accuracy: 0.5000 - loss: 1.3920
# Epoch 10: val_loss did not improve from 1.41196
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.3920 - val_accuracy: 0.4514 - val_loss: 1.4175 - learning_rate: 0.0010
# Epoch 11/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4169 - loss: 1.5032
# Epoch 11: val_loss improved from 1.41196 to 1.34204, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.4169 - loss: 1.5032 - val_accuracy: 0.4891 - val_loss: 1.3420 - learning_rate: 0.0010
# Epoch 12/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:14 83ms/step - accuracy: 0.4375 - loss: 1.5089
# Epoch 12: val_loss did not improve from 1.34204
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.4375 - loss: 1.5089 - val_accuracy: 0.4896 - val_loss: 1.3423 - learning_rate: 0.0010
# Epoch 13/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4271 - loss: 1.4754
# Epoch 13: val_loss improved from 1.34204 to 1.33059, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.4271 - loss: 1.4754 - val_accuracy: 0.4855 - val_loss: 1.3306 - learning_rate: 0.0010
# Epoch 14/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:20 89ms/step - accuracy: 0.3750 - loss: 1.5143
# Epoch 14: val_loss did not improve from 1.33059
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3750 - loss: 1.5143 - val_accuracy: 0.4854 - val_loss: 1.3317 - learning_rate: 0.0010
# Epoch 15/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4466 - loss: 1.4455
# Epoch 15: val_loss improved from 1.33059 to 1.31340, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 77s 85ms/step - accuracy: 0.4466 - loss: 1.4454 - val_accuracy: 0.5025 - val_loss: 1.3134 - learning_rate: 0.0010
# Epoch 16/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:20 89ms/step - accuracy: 0.4375 - loss: 1.4584
# Epoch 16: val_loss did not improve from 1.31340
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4375 - loss: 1.4584 - val_accuracy: 0.5022 - val_loss: 1.3134 - learning_rate: 0.0010
# Epoch 17/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4544 - loss: 1.4220
# Epoch 17: val_loss improved from 1.31340 to 1.29049, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.4544 - loss: 1.4220 - val_accuracy: 0.5107 - val_loss: 1.2905 - learning_rate: 0.0010
# Epoch 18/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 77ms/step - accuracy: 0.5000 - loss: 1.5283
# Epoch 18: val_loss did not improve from 1.29049
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.5283 - val_accuracy: 0.5106 - val_loss: 1.2912 - learning_rate: 0.0010
# Epoch 19/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4613 - loss: 1.4139
# Epoch 19: val_loss improved from 1.29049 to 1.26318, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.4613 - loss: 1.4139 - val_accuracy: 0.5199 - val_loss: 1.2632 - learning_rate: 0.0010
# Epoch 20/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:15 84ms/step - accuracy: 0.2188 - loss: 1.6670
# Epoch 20: val_loss did not improve from 1.26318
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.2188 - loss: 1.6670 - val_accuracy: 0.5194 - val_loss: 1.2638 - learning_rate: 0.0010
# Epoch 21/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4673 - loss: 1.3865
# Epoch 21: val_loss did not improve from 1.26318
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.4673 - loss: 1.3865 - val_accuracy: 0.5145 - val_loss: 1.2670 - learning_rate: 0.0010
# Epoch 22/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:21 91ms/step - accuracy: 0.2812 - loss: 1.7373
# Epoch 22: val_loss improved from 1.26318 to 1.26179, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.2812 - loss: 1.7373 - val_accuracy: 0.5152 - val_loss: 1.2618 - learning_rate: 0.0010
# Epoch 23/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4728 - loss: 1.3719
# Epoch 23: val_loss improved from 1.26179 to 1.22772, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.4728 - loss: 1.3719 - val_accuracy: 0.5361 - val_loss: 1.2277 - learning_rate: 0.0010
# Epoch 24/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:26 97ms/step - accuracy: 0.5000 - loss: 1.3341
# Epoch 24: val_loss did not improve from 1.22772
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.3341 - val_accuracy: 0.5352 - val_loss: 1.2291 - learning_rate: 0.0010
# Epoch 25/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4823 - loss: 1.3658
# Epoch 25: val_loss improved from 1.22772 to 1.22425, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.4823 - loss: 1.3658 - val_accuracy: 0.5387 - val_loss: 1.2243 - learning_rate: 0.0010
# Epoch 26/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:15 84ms/step - accuracy: 0.6250 - loss: 1.1346
# Epoch 26: val_loss improved from 1.22425 to 1.22404, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6250 - loss: 1.1346 - val_accuracy: 0.5387 - val_loss: 1.2240 - learning_rate: 0.0010
# Epoch 27/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4812 - loss: 1.3586
# Epoch 27: val_loss did not improve from 1.22404
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.4812 - loss: 1.3586 - val_accuracy: 0.5249 - val_loss: 1.2331 - learning_rate: 0.0010
# Epoch 28/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:19 89ms/step - accuracy: 0.5312 - loss: 1.1887
# Epoch 28: val_loss did not improve from 1.22404
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5312 - loss: 1.1887 - val_accuracy: 0.5238 - val_loss: 1.2336 - learning_rate: 0.0010
# Epoch 29/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4922 - loss: 1.3430
# Epoch 29: val_loss improved from 1.22404 to 1.21585, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 73s 81ms/step - accuracy: 0.4922 - loss: 1.3430 - val_accuracy: 0.5350 - val_loss: 1.2159 - learning_rate: 0.0010
# Epoch 30/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:15 84ms/step - accuracy: 0.5000 - loss: 1.1733
# Epoch 30: val_loss did not improve from 1.21585
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.1733 - val_accuracy: 0.5351 - val_loss: 1.2169 - learning_rate: 0.0010
# Epoch 31/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4866 - loss: 1.3458
# Epoch 31: val_loss improved from 1.21585 to 1.18920, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.4866 - loss: 1.3458 - val_accuracy: 0.5535 - val_loss: 1.1892 - learning_rate: 0.0010
# Epoch 32/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:18 88ms/step - accuracy: 0.4688 - loss: 1.3565
# Epoch 32: val_loss did not improve from 1.18920
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4688 - loss: 1.3565 - val_accuracy: 0.5515 - val_loss: 1.1899 - learning_rate: 0.0010
# Epoch 33/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4901 - loss: 1.3243
# Epoch 33: val_loss did not improve from 1.18920
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.4901 - loss: 1.3243 - val_accuracy: 0.5458 - val_loss: 1.1981 - learning_rate: 0.0010
# Epoch 34/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:15 84ms/step - accuracy: 0.5625 - loss: 1.2539
# Epoch 34: val_loss did not improve from 1.18920
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5625 - loss: 1.2539 - val_accuracy: 0.5457 - val_loss: 1.1956 - learning_rate: 0.0010
# Epoch 35/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4988 - loss: 1.3240
# Epoch 35: val_loss did not improve from 1.18920
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.4988 - loss: 1.3240 - val_accuracy: 0.5369 - val_loss: 1.2080 - learning_rate: 0.0010
# Epoch 36/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:09 78ms/step - accuracy: 0.3438 - loss: 1.2693
# Epoch 36: val_loss did not improve from 1.18920
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3438 - loss: 1.2693 - val_accuracy: 0.5378 - val_loss: 1.2070 - learning_rate: 0.0010
# Epoch 37/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5028 - loss: 1.3182
# Epoch 37: val_loss improved from 1.18920 to 1.18294, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5028 - loss: 1.3182 - val_accuracy: 0.5496 - val_loss: 1.1829 - learning_rate: 0.0010
# Epoch 38/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:21 91ms/step - accuracy: 0.4375 - loss: 1.3867
# Epoch 38: val_loss did not improve from 1.18294
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4375 - loss: 1.3867 - val_accuracy: 0.5486 - val_loss: 1.1842 - learning_rate: 0.0010
# Epoch 39/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4968 - loss: 1.3147
# Epoch 39: val_loss improved from 1.18294 to 1.16541, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.4968 - loss: 1.3147 - val_accuracy: 0.5621 - val_loss: 1.1654 - learning_rate: 0.0010
# Epoch 40/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:11 80ms/step - accuracy: 0.4688 - loss: 1.4287
# Epoch 40: val_loss did not improve from 1.16541
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4688 - loss: 1.4287 - val_accuracy: 0.5621 - val_loss: 1.1655 - learning_rate: 0.0010
# Epoch 41/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4995 - loss: 1.3196
# Epoch 41: val_loss did not improve from 1.16541
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.4995 - loss: 1.3196 - val_accuracy: 0.5522 - val_loss: 1.1777 - learning_rate: 0.0010
# Epoch 42/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:16 85ms/step - accuracy: 0.5312 - loss: 1.0931
# Epoch 42: val_loss did not improve from 1.16541
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5312 - loss: 1.0931 - val_accuracy: 0.5511 - val_loss: 1.1777 - learning_rate: 0.0010
# Epoch 43/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5018 - loss: 1.3090
# Epoch 43: val_loss improved from 1.16541 to 1.14886, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.5018 - loss: 1.3090 - val_accuracy: 0.5641 - val_loss: 1.1489 - learning_rate: 0.0010
# Epoch 44/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:24 94ms/step - accuracy: 0.5000 - loss: 1.1497
# Epoch 44: val_loss improved from 1.14886 to 1.14811, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.1497 - val_accuracy: 0.5653 - val_loss: 1.1481 - learning_rate: 0.0010
# Epoch 45/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4964 - loss: 1.3079
# Epoch 45: val_loss did not improve from 1.14811
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.4964 - loss: 1.3079 - val_accuracy: 0.5532 - val_loss: 1.1787 - learning_rate: 0.0010
# Epoch 46/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:24 95ms/step - accuracy: 0.5312 - loss: 1.3951
# Epoch 46: val_loss did not improve from 1.14811
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5312 - loss: 1.3951 - val_accuracy: 0.5532 - val_loss: 1.1755 - learning_rate: 0.0010
# Epoch 47/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5038 - loss: 1.2916
# Epoch 47: val_loss improved from 1.14811 to 1.13653, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 76s 85ms/step - accuracy: 0.5038 - loss: 1.2916 - val_accuracy: 0.5729 - val_loss: 1.1365 - learning_rate: 0.0010
# Epoch 48/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:15 84ms/step - accuracy: 0.5625 - loss: 1.3559
# Epoch 48: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5625 - loss: 1.3559 - val_accuracy: 0.5709 - val_loss: 1.1366 - learning_rate: 0.0010
# Epoch 49/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5061 - loss: 1.2992
# Epoch 49: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5061 - loss: 1.2992 - val_accuracy: 0.5587 - val_loss: 1.1628 - learning_rate: 0.0010
# Epoch 50/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 2:15 151ms/step - accuracy: 0.4375 - loss: 1.2996
# Epoch 50: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4375 - loss: 1.2996 - val_accuracy: 0.5570 - val_loss: 1.1648 - learning_rate: 0.0010
# Epoch 51/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5118 - loss: 1.2887
# Epoch 51: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 76s 85ms/step - accuracy: 0.5118 - loss: 1.2887 - val_accuracy: 0.5478 - val_loss: 1.1620 - learning_rate: 0.0010
# Epoch 52/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:18 88ms/step - accuracy: 0.5000 - loss: 1.2525
# Epoch 52: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.2525 - val_accuracy: 0.5475 - val_loss: 1.1620 - learning_rate: 0.0010
# Epoch 53/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5097 - loss: 1.2797
# Epoch 53: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5097 - loss: 1.2797 - val_accuracy: 0.5609 - val_loss: 1.1434 - learning_rate: 0.0010
# Epoch 54/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:16 85ms/step - accuracy: 0.6250 - loss: 1.0880
# Epoch 54: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6250 - loss: 1.0880 - val_accuracy: 0.5607 - val_loss: 1.1440 - learning_rate: 0.0010
# Epoch 55/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5069 - loss: 1.2904
# Epoch 55: val_loss did not improve from 1.13653
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5069 - loss: 1.2904 - val_accuracy: 0.5632 - val_loss: 1.1372 - learning_rate: 0.0010
# Epoch 56/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:19 89ms/step - accuracy: 0.5312 - loss: 1.0944
# Epoch 56: val_loss improved from 1.13653 to 1.13618, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5312 - loss: 1.0944 - val_accuracy: 0.5644 - val_loss: 1.1362 - learning_rate: 0.0010
# Epoch 57/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5115 - loss: 1.2771
# Epoch 57: val_loss did not improve from 1.13618
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 78s 87ms/step - accuracy: 0.5115 - loss: 1.2771 - val_accuracy: 0.5539 - val_loss: 1.1704 - learning_rate: 0.0010
# Epoch 58/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 77ms/step - accuracy: 0.6875 - loss: 1.2768
# Epoch 58: val_loss did not improve from 1.13618
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.6875 - loss: 1.2768 - val_accuracy: 0.5561 - val_loss: 1.1625 - learning_rate: 0.0010
# Epoch 59/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5086 - loss: 1.2835
# Epoch 59: val_loss did not improve from 1.13618
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.5086 - loss: 1.2835 - val_accuracy: 0.5674 - val_loss: 1.1375 - learning_rate: 0.0010
# Epoch 60/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:11 80ms/step - accuracy: 0.5312 - loss: 1.2373
# Epoch 60: val_loss did not improve from 1.13618
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5312 - loss: 1.2373 - val_accuracy: 0.5673 - val_loss: 1.1363 - learning_rate: 0.0010
# Epoch 61/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5139 - loss: 1.2815
# Epoch 61: val_loss improved from 1.13618 to 1.13451, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.5139 - loss: 1.2815 - val_accuracy: 0.5638 - val_loss: 1.1345 - learning_rate: 0.0010
# Epoch 62/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 77ms/step - accuracy: 0.4688 - loss: 1.3026
# Epoch 62: val_loss did not improve from 1.13451
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4688 - loss: 1.3026 - val_accuracy: 0.5628 - val_loss: 1.1346 - learning_rate: 0.0010
# Epoch 63/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5118 - loss: 1.2833
# Epoch 63: val_loss improved from 1.13451 to 1.12983, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5118 - loss: 1.2833 - val_accuracy: 0.5644 - val_loss: 1.1298 - learning_rate: 0.0010
# Epoch 64/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:14 83ms/step - accuracy: 0.5938 - loss: 1.2519
# Epoch 64: val_loss improved from 1.12983 to 1.12885, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5938 - loss: 1.2519 - val_accuracy: 0.5646 - val_loss: 1.1288 - learning_rate: 0.0010
# Epoch 65/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5139 - loss: 1.2774
# Epoch 65: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.5139 - loss: 1.2774 - val_accuracy: 0.5651 - val_loss: 1.1354 - learning_rate: 0.0010
# Epoch 66/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 76ms/step - accuracy: 0.5938 - loss: 1.2829
# Epoch 66: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5938 - loss: 1.2829 - val_accuracy: 0.5655 - val_loss: 1.1379 - learning_rate: 0.0010
# Epoch 67/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5158 - loss: 1.2679
# Epoch 67: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5158 - loss: 1.2679 - val_accuracy: 0.5684 - val_loss: 1.1370 - learning_rate: 0.0010
# Epoch 68/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:09 77ms/step - accuracy: 0.4062 - loss: 1.3193
# Epoch 68: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4062 - loss: 1.3193 - val_accuracy: 0.5706 - val_loss: 1.1336 - learning_rate: 0.0010
# Epoch 69/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5215 - loss: 1.2717
# Epoch 69: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5215 - loss: 1.2717 - val_accuracy: 0.5585 - val_loss: 1.1364 - learning_rate: 0.0010
# Epoch 70/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:07 75ms/step - accuracy: 0.5938 - loss: 1.1024
# Epoch 70: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5938 - loss: 1.1024 - val_accuracy: 0.5587 - val_loss: 1.1364 - learning_rate: 0.0010
# Epoch 71/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5195 - loss: 1.2699
# Epoch 71: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 76s 85ms/step - accuracy: 0.5195 - loss: 1.2699 - val_accuracy: 0.5587 - val_loss: 1.1366 - learning_rate: 0.0010
# Epoch 72/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:09 77ms/step - accuracy: 0.5000 - loss: 1.2848
# Epoch 72: val_loss did not improve from 1.12885
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5000 - loss: 1.2848 - val_accuracy: 0.5591 - val_loss: 1.1378 - learning_rate: 0.0010
# Epoch 73/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5231 - loss: 1.2568
# Epoch 73: val_loss improved from 1.12885 to 1.10883, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.5231 - loss: 1.2568 - val_accuracy: 0.5761 - val_loss: 1.1088 - learning_rate: 0.0010
# Epoch 74/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:15 85ms/step - accuracy: 0.3750 - loss: 1.3391
# Epoch 74: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3750 - loss: 1.3391 - val_accuracy: 0.5762 - val_loss: 1.1097 - learning_rate: 0.0010
# Epoch 75/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5204 - loss: 1.2592
# Epoch 75: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.5204 - loss: 1.2592 - val_accuracy: 0.5677 - val_loss: 1.1197 - learning_rate: 0.0010
# Epoch 76/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 76ms/step - accuracy: 0.5000 - loss: 1.1926
# Epoch 76: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5000 - loss: 1.1926 - val_accuracy: 0.5688 - val_loss: 1.1179 - learning_rate: 0.0010
# Epoch 77/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5246 - loss: 1.2582
# Epoch 77: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5246 - loss: 1.2582 - val_accuracy: 0.5719 - val_loss: 1.1108 - learning_rate: 0.0010
# Epoch 78/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:06 74ms/step - accuracy: 0.5312 - loss: 1.2810
# Epoch 78: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5312 - loss: 1.2810 - val_accuracy: 0.5715 - val_loss: 1.1120 - learning_rate: 0.0010
# Epoch 79/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5245 - loss: 1.2557
# Epoch 79: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 82ms/step - accuracy: 0.5245 - loss: 1.2557 - val_accuracy: 0.5731 - val_loss: 1.1110 - learning_rate: 0.0010
# Epoch 80/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:11 79ms/step - accuracy: 0.5625 - loss: 1.1714
# Epoch 80: val_loss did not improve from 1.10883
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5625 - loss: 1.1714 - val_accuracy: 0.5699 - val_loss: 1.1145 - learning_rate: 0.0010
# Epoch 81/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5237 - loss: 1.2491
# Epoch 81: val_loss improved from 1.10883 to 1.10538, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5237 - loss: 1.2491 - val_accuracy: 0.5738 - val_loss: 1.1054 - learning_rate: 0.0010
# Epoch 82/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:06 74ms/step - accuracy: 0.5000 - loss: 1.3902
# Epoch 82: val_loss did not improve from 1.10538
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 1.3902 - val_accuracy: 0.5741 - val_loss: 1.1060 - learning_rate: 0.0010
# Epoch 83/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5215 - loss: 1.2572
# Epoch 83: val_loss did not improve from 1.10538
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5215 - loss: 1.2572 - val_accuracy: 0.5779 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 84/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:05 74ms/step - accuracy: 0.5625 - loss: 1.0443
# Epoch 84: val_loss did not improve from 1.10538
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5625 - loss: 1.0443 - val_accuracy: 0.5772 - val_loss: 1.1065 - learning_rate: 0.0010
# Epoch 85/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5220 - loss: 1.2590
# Epoch 85: val_loss did not improve from 1.10538
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5220 - loss: 1.2590 - val_accuracy: 0.5662 - val_loss: 1.1312 - learning_rate: 0.0010
# Epoch 86/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:11 80ms/step - accuracy: 0.5625 - loss: 1.1669
# Epoch 86: val_loss did not improve from 1.10538
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5625 - loss: 1.1669 - val_accuracy: 0.5658 - val_loss: 1.1322 - learning_rate: 0.0010
# Epoch 87/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5226 - loss: 1.2483
# Epoch 87: val_loss improved from 1.10538 to 1.10421, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5226 - loss: 1.2483 - val_accuracy: 0.5793 - val_loss: 1.1042 - learning_rate: 0.0010
# Epoch 88/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:13 82ms/step - accuracy: 0.4688 - loss: 1.2684
# Epoch 88: val_loss did not improve from 1.10421
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4688 - loss: 1.2684 - val_accuracy: 0.5787 - val_loss: 1.1057 - learning_rate: 0.0010
# Epoch 89/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5260 - loss: 1.2496
# Epoch 89: val_loss did not improve from 1.10421
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5260 - loss: 1.2496 - val_accuracy: 0.5649 - val_loss: 1.1304 - learning_rate: 0.0010
# Epoch 90/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:09 78ms/step - accuracy: 0.4688 - loss: 1.1606
# Epoch 90: val_loss did not improve from 1.10421
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4688 - loss: 1.1606 - val_accuracy: 0.5639 - val_loss: 1.1327 - learning_rate: 0.0010
# Epoch 91/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5284 - loss: 1.2417
# Epoch 91: val_loss did not improve from 1.10421
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 74s 83ms/step - accuracy: 0.5284 - loss: 1.2417 - val_accuracy: 0.5620 - val_loss: 1.1417 - learning_rate: 0.0010
# Epoch 92/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:18 87ms/step - accuracy: 0.4688 - loss: 1.2090
# Epoch 92: val_loss did not improve from 1.10421
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4688 - loss: 1.2090 - val_accuracy: 0.5607 - val_loss: 1.1445 - learning_rate: 0.0010
# Epoch 93/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5271 - loss: 1.2359
# Epoch 93: val_loss did not improve from 1.10421
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 77s 85ms/step - accuracy: 0.5271 - loss: 1.2360 - val_accuracy: 0.5708 - val_loss: 1.1068 - learning_rate: 0.0010
# Epoch 94/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 76ms/step - accuracy: 0.4375 - loss: 1.3738
# Epoch 94: val_loss improved from 1.10421 to 1.10384, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4375 - loss: 1.3738 - val_accuracy: 0.5727 - val_loss: 1.1038 - learning_rate: 0.0010
# Epoch 95/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5290 - loss: 1.2352
# Epoch 95: val_loss did not improve from 1.10384
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 76s 84ms/step - accuracy: 0.5290 - loss: 1.2352 - val_accuracy: 0.5814 - val_loss: 1.1064 - learning_rate: 0.0010
# Epoch 96/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:14 84ms/step - accuracy: 0.5000 - loss: 1.3566
# Epoch 96: val_loss did not improve from 1.10384
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5000 - loss: 1.3566 - val_accuracy: 0.5825 - val_loss: 1.1050 - learning_rate: 0.0010
# Epoch 97/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5289 - loss: 1.2406
# Epoch 97: val_loss improved from 1.10384 to 1.09131, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 83ms/step - accuracy: 0.5289 - loss: 1.2406 - val_accuracy: 0.5795 - val_loss: 1.0913 - learning_rate: 0.0010
# Epoch 98/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:11 80ms/step - accuracy: 0.5312 - loss: 1.0955
# Epoch 98: val_loss improved from 1.09131 to 1.09097, saving model to models/emotion_model.keras
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5312 - loss: 1.0955 - val_accuracy: 0.5800 - val_loss: 1.0910 - learning_rate: 0.0010
# Epoch 99/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5301 - loss: 1.2420
# Epoch 99: val_loss did not improve from 1.09097
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 75s 84ms/step - accuracy: 0.5301 - loss: 1.2420 - val_accuracy: 0.5816 - val_loss: 1.1132 - learning_rate: 0.0010
# Epoch 100/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:08 76ms/step - accuracy: 0.5000 - loss: 1.2947
# Epoch 100: val_loss did not improve from 1.09097
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5000 - loss: 1.2947 - val_accuracy: 0.5818 - val_loss: 1.1157 - learning_rate: 0.0010

# %%
model.save(base_path + '_final.keras')

# %%
val_loss, val_accuracy = model.evaluate(xtest, ytest, verbose=0)
print(f"\n✅ Final Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# ✅ Final Validation Accuracy: 58.18%

# %%
import cv2
import imutils
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import numpy as np

# Load saved model
emotion_model_path = base_path + '_final.keras'
emotion_classifier = load_model(emotion_model_path)
EMOTIONS = ["angry", "disgust", "fear", "happy", "sad", "surprised", "neutral"]

# Load face detector
face_detector = cv2.CascadeClassifier('haarcascade_files/haarcascade_frontalface_default.xml')

cv2.namedWindow('Emotion Detector', cv2.WINDOW_NORMAL)
camera = cv2.VideoCapture(0)

while True:
    ret, frame = camera.read()
    if not ret:
        break

    frame = imutils.resize(frame, width=500)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)
    frameClone = frame.copy()

    if len(faces) > 0:
        (fX, fY, fW, fH) = sorted(faces, reverse=True, key=lambda x: x[2] * x[3])[0]
        roi = gray[fY:fY + fH, fX:fX + fW]
        roi = cv2.resize(roi, (48, 48))
        roi = roi.astype("float") / 255.0
        roi = img_to_array(roi)
        roi = np.expand_dims(roi, axis=0)

        preds = emotion_classifier.predict(roi, verbose=0)[0]
        label = EMOTIONS[preds.argmax()]

        cv2.rectangle(frameClone, (fX, fY), (fX + fW, fY + fH), (147, 112, 219), 3)
        cv2.putText(frameClone, label.upper(), (fX, fY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2)

    cv2.rectangle(frameClone, (0, 0), (500, 40), (50, 50, 50), -1)
    cv2.putText(frameClone, "Real-Time Emotion Recognition", (10, 30), cv2.FONT_HERSHEY_DUPLEX, 0.8, (0, 255, 255), 2)
    cv2.imshow('Emotion Detector', frameClone)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 19
#      16 camera = cv2.VideoCapture(0)
#      18 while True:
# ---> 19     ret, frame = camera.read()
#      20     if not ret:
#      21         break
#
# KeyboardInterrupt:

# %%
model.save('trained_emotion_model.keras')  # Saved in the root folder
